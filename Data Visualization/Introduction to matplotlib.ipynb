# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
x = np.arange(0,10)
y = x ** 2

# %%
plt.plot(x,y)

# %%
plt.plot(y,x,'r*-')
plt.show()

# %%
fig = plt.figure()
axes = fig.add_axes([0.3,0.3,0.3,0.3])
axes2 = fig.add_axes([0.5,0.5,0.5,0.5])

# %%
fig=plt.figure()
ax=fig.add_axes([0.1,0.2,0.8,0.8])
ax1=fig.add_axes([0.2,0.4,0.2,0.4])

# %%
fig = plt.figure()
axes = fig.add_axes([1,1,1,1])
axes2 = fig.add_axes([1.3,1.2,0.3,0.6])

# %%
x = np.arange(-5*np.pi,5*np.pi)
plt.subplot(211)
plt.plot(x,np.sin(x),'b')
plt.subplot(212)
plt.plot(x,np.cos(x),'r')

# %%
plt.subplot(121)
plt.plot(x,y)
plt.subplot(122)
plt.plot(y,x)

# %%
fig = plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax1.plot(y,x,'b*-')
ax2 = fig.add_axes([0.5,0.1,.4,.5])
ax2.plot(x,y,'r+-')

# %%
fig = plt.figure()
fig.add_axes([0,0,1,1])
fig.add_subplot(221)
fig.add_subplot(222)

# %%
from random import sample
data = sample(range(1,100),10)
plt.hist(data)
plt.savefig('mygraph.png')
